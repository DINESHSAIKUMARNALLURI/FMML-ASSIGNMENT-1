# %% [markdown]
# <a href="https://colab.research.google.com/github/DINESHSAIKUMARNALLURI/FMML-ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-04 06:21:48--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   218MB/s    in 0.3s
#
# 2023-05-04 06:21:49 (218 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 15268   1003.0206v1  Hidden Markov models (HMMs) have been successf...    cs
# 2303   1802.08718v1  Consider a platform that wants to learn a pers...  stat
# 30535  1712.04851v1  In this paper we study 3D convolutional networ...    cs
# 13515   1406.5633v2  We introduce a technology stack or specificati...    cs
# 10252   0908.0050v2  Sparse coding--that is, modelling data vectors...  stat
# ...             ...                                                ...   ...
# 40916   1112.1615v1  The new model that we present in this paper is...    cs
# 32466   1112.3714v1  We show how to incorporate information from la...    cs
# 28546  1707.00408v1  Person re-identification (person re-ID) is mos...    cs
# 8632   1708.04675v1  Convolution Neural Networks on Graphs are impo...    cs
# 10591   1309.6852v1  This paper addresses the problem of rank aggre...    cs
#
#                                                    title  year  \
# 15268  Why has (reasonably accurate) Automatic Speech...  2010
# 2303                           Learning with Abandonment  2018
# 30535  Rethinking Spatiotemporal Feature Learning For...  2017
# 13515                 Thermodynamic-RAM Technology Stack  2014
# 10252  Online Learning for Matrix Factorization and S...  2009
# ...                                                  ...   ...
# 40916  SLA Establishment with Guaranteed QoS in the I...  2011
# 32466  Nonnegative Matrix Factorization for Semi-supe...  2011
# 28546  Pedestrian Alignment Network for Large-scale P...  2017
# 8632   Learning Graph While Training: An Evolving Gra...  2017
# 10591                        Stochastic Rank Aggregation  2013
#
#                                                 keywords
# 15268  [successfully, automatic, recognition, assumpt...
# 2303   [personalized, abandoning, dissatisfied, inter...
# 30535  [convolutional, understanding, inception, arch...
# 13515  [introduce, technology, specification, describ...
# 10252  [modelling, combinations, neuroscience, proces...
# ...                                                  ...
# 40916  [introduced, guaranteed, resources, management...
# 32466  [incorporate, information, nonnegative, factor...
# 28546  [identification, retrieval, automatic, detecto...
# 8632   [convolution, important, generalization, exten...
# 10591  [addresses, aggregation, consensus, traditiona...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 15268    [successfully, automatic, recognition, assumpt...
# 2303     [personalized, abandoning, dissatisfied, inter...
# 30535    [convolutional, understanding, inception, arch...
# 13515    [introduce, technology, specification, describ...
# 10252    [modelling, combinations, neuroscience, proces...
#                                ...
# 11230    [projections, processing, applications, classi...
# 22798    [introduced, phalanxes, detection, classificat...
# 21598    [membership, generated, stochastic, blockmodel...
# 31952    [embedding, relations, knowledge, dimensional,...
# 3681     [approximate, posterior, distribution, variati...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8781 words.
# Out of those 4571 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="45e4f72a-3f15-4a27-9741-c9a322632ff6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45e4f72a-3f15-4a27-9741-c9a322632ff6")) {                    Plotly.newPlot(                        "45e4f72a-3f15-4a27-9741-c9a322632ff6",                        [{"x":["available","alternative","demonstrate","departure","significant","automatic","consensus","statistical","negligible","responsible","structure","statistics","demonstrates","manipulations","obviously","exploration","commercially","improving","assumption","preliminary","diagnostic","successfully","simulation","resampling","hypothesis","recognition","resulting","independence","resampled","contemporary","dependency","dependence","understanding","scenarios","thresholded","interacting","furthermore","guarantees","efficiently","heterogeneity","algorithms","investigate","interested","abandoning","personalization","population","personalized","performance","separable","transferred","replacing","deflating","spatiotemporal","contribute","classification","architecture","interestingly","computationally","convolution","indicates","rethinking","convolutional","outperforms","efficient","capturing","inception","convolutions","detection","understand","processor","specialization","explaining","separation","described","bottleneck","presenting","neuromorphic","abstraction","traditional","previously","memristor","integrate","advantages","computation","implementation","platforms","architectures","computing","introduce","currently","technology","specification","processing","instruction","difficult","describing","principles","capabilities","implement","optimization","combinations","factorization","formulations","principal","demonstrating","experiments","dictionary","stochastic","component","variations","convergence","naturally","algorithm","modelling","gracefully","presented","approximations","neuroscience","experimentation","mechanical","conditions","simulations","limitation","plentiful","engineering","approaches","summarize","generalize","predictive","predicting","inexpensive","environment","different","increasingly","computational","interaction","partially","psychology","cognitive","reinforcement","essential","properties","normative","observable","implemented","processes","behavioral","functions","benchmark","applicable","characteristics","technique","dirichlet","generalized","qualities","synthetic","unsupervised","modification","backgrounds","occlusion","performing","demonstrated","localization","framework","describes","inference","arbitrary","accomplish","extracted","represent","dependent","illustrate","distribution","mimicking","illustration","expansion","controller","variables","posterior","predictions","parameter","estimated","respectively","pertinent","important","extraction","prediction","interpretability","universal","outperformed","developed","molecular","simultaneously","evaluation","compounds","constructed","containing","selection","objectives","descriptors"],"y":[329,81,526,5,260,188,20,155,11,14,343,71,52,6,6,66,2,95,75,50,22,82,73,6,55,399,151,31,1,13,48,22,176,78,0,21,170,57,152,7,581,158,31,1,3,43,15,936,10,17,16,1,18,28,523,246,22,102,56,24,2,400,261,409,37,15,12,355,66,9,3,12,27,67,25,24,13,20,183,120,3,53,96,146,134,25,144,127,348,63,39,22,300,3,158,29,29,42,65,308,33,44,28,34,30,643,58,119,104,87,111,48,823,52,1,184,25,10,16,10,135,37,28,1,63,449,12,43,47,81,6,108,744,53,275,83,50,12,60,114,78,200,8,28,102,111,17,223,212,47,82,253,22,67,8,139,143,23,4,34,81,107,62,527,90,193,95,19,114,109,78,83,213,4,3,20,11,123,38,89,116,55,82,0,357,150,232,16,45,16,192,8,112,239,3,65,67,154,34,40],"type":"bar"},{"x":["available","alternative","demonstrate","departure","significant","automatic","consens ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4571,), (4571, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8091666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Query</span> <span style=''>DAGs</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Practical</span> <span style=''>Paradigm</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3191489361702127);'>Implementing</span> <span style=''>Belief</span> <span style=''>Network</span> <span style='background-color:rgba(255, 0, 0, 0.32869565217391306);'>Inference</span> <br/><br/><span style=''>We</span> <span style=''>describe</span> <span style=''>a</span> <span style=''>new</span> <span style=''>paradigm</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3191489361702127);'>implementing</span> <span style='background-color:rgba(255, 0, 0, 0.32869565217391306);'>inference</span> <span style=''>in</span> <span style=''>belief</span> <span style=''>networks</span> <span style=''>which</span> <span style=''>consists</span> <span style=''>of</span> <span style=''>two</span> <span style=''>steps</span> <span style=''>(1)</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>compiling</span> <span style=''>a</span> <span style=''>belief</span> <span style=''>network</span> <span style=''>into</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arithmetic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expression</span> <span style=''>called</span> <span style=''>a</span> <span style=''>Query</span> <span style=''>DAG</span> <span style=''>(Q</span> <span style=''>DAG)</span> <span style=''>and</span> <span style=''>(2)</span> <span style='background-color:rgba(0, 255, 0, 0.7101449275362319);'>answering</span> <span style=''>queries</span> <span style=''>using</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.39766081871345016);'>evaluation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>Each</span> <span style=''>node</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Q</span> <span style=''>DAG</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>represents</span> <span style=''>a</span> <span style=''>numeric</span> <span style='background-color:rgba(0, 255, 0, 0.5405405405405406);'>operation</span> <span style=''>a</span> <span style=''>number</span> <span style=''>or</span> <span style=''>a</span> <span style=''>symbol</span> <span style=''>for</span> <span style=''>evidence</span> <span style=''>Each</span> <span style=''>leaf</span> <span style=''>node</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Q</span> <span style=''>DAG</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>represents</span> <span style=''>the</span> <span style=''>answer</span> <span style=''>to</span> <span style=''>a</span> <span style=''>network</span> <span style=''>query</span> <span style=''>that</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>of</span> <span style=''>some</span> <span style=''>event</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>It</span> <span style=''>appears</span> <span style=''>that</span> <span style=''>Q</span> <span style=''>DAGs</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>using</span> <span style=''>any</span> <span style=''>of</span> <span style=''>the</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>exact</span> <span style='background-color:rgba(255, 0, 0, 0.32869565217391306);'>inference</span> <span style=''>in</span> <span style=''>belief</span> <span style=''>networks</span> <span style=''>(we</span> <span style=''>show</span> <span style=''>how</span> <span style=''>they</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style=''>Models</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Relational</span> <span style=''>Data</span> <span style=''>with</span> <span style=''>Side</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Information</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>overlapping</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>community</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discovery</span> <span style=''>and</span> <span style=''>link</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relational</span> <span style=''>data</span> <span style=''>given</span> <span style=''>as</span> <span style=''>a</span> <span style=''>graph</span> <span style=''>The</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>has</span> <span style=''>(1)</span> <span style=''>a</span> <span style=''>deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>which</span> <span style=''>enables</span> <span style=''>us</span> <span style=''>to</span> <span style=''>infer</span> <span style=''>multiple</span> <span style=''>layers</span> <span style=''>of</span> <span style=''>latent</span> <span style=''>featurescommunities</span> <span style=''>for</span> <span style=''>each</span> <span style=''>node</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style=''>superior</span> <span style=''>link</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>on</span> <span style=''>more</span> <span style=''>complex</span> <span style=''>networks</span> <span style=''>and</span> <span style=''>better</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>of</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>features</span> <span style=''>and</span> <span style=''>(2)</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>model</span> <span style=''>which</span> <span style=''>allows</span> <span style=''>directly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditioning</span> <span style=''>the</span> <span style=''>node</span> <span style=''>latent</span> <span style=''>features</span> <span style=''>on</span> <span style=''>the</span> <span style=''>side</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>in</span> <span style=''>form</span> <span style=''>of</span> <span style=''>node</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attributes</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>handles</span> <span style=''>both</span> <span style=''>(1)</span> <span style=''>and</span> <span style=''>(2)</span> <span style=''>via</span> <span style=''>a</span> <span style=''>clean</span> <span style=''>unified</span> <span style=''>model</span> <span style=''>which</span> <span style=''>enjoys</span> <span style=''>full</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conjugacy</span> <span style=''>via</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3); ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.6111111111111112);'>Hyperparameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>A</span> <span style=''>Spectral</span> <span style=''>Approach</span> <br/><br/><span style=''>We</span> <span style=''>give</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.6111111111111112);'>hyperparameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>inspired</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>from</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>Boolean</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>We</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>the</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.32513181019332177);'>dimensional</span> <span style=''>regime</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>canonical</span> <span style=''>example</span> <span style=''>is</span> <span style=''>training</span> <span style=''>a</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>with</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.6923076923076924);'>hyperparameters</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compressed</span> <span style=''>sensing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>orthogonal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomials</span> <span style=''>requires</span> <span style=''>only</span> <span style=''>uniform</span> <span style=''>sampling</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6923076923076924);'>hyperparameters</span> <span style=''>and</span> <span style=''>is</span> <span style=''>thus</span> <span style=''>easily</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parallelizable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Experiments</span> <span style=''>for</span> <span style=''>training</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>on</span> <span style=''>Cifar</span> <span style=''>10</span> <span style=''>show</span> <span style=''>that</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>tools</span> <span style=''>(eg</span> <span style=''>Hyperband</span> <span style=''>and</span> <span style=''>Spearmint)</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>finds</span> <span style='background-color:rgba(0, 255, 0, 0.3070539419087137);'>significantly</span> <span style=''>improved</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>in</span> <span style=''>some</span> <span style=''>cases</span> <span style=''>better</span> <span style=''>than</span> <span style=''>what</span> <span style=''>is</span> <span style='backgrou ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style=''>Poisson</span> <span style=''>Tucker</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Decomposition</span> <span style=''>for</span> <span style=''>Learning</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structure</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>International</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Relations</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>Bayesian</span> <span style=''>Poisson</span> <span style=''>Tucker</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>(BPTD)</span> <span style=''>for</span> <span style=''>modeling</span> <span style=''>country</span> <span style=''>country</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interaction</span> <span style=''>event</span> <span style=''>data</span> <span style=''>These</span> <span style=''>data</span> <span style=''>consist</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interaction</span> <span style=''>events</span> <span style=''>of</span> <span style=''>the</span> <span style=''>form</span> <span style=''>country</span> <span style=''>i</span> <span style=''>took</span> <span style=''>action</span> <span style=''>a</span> <span style=''>toward</span> <span style=''>country</span> <span style=''>j</span> <span style=''>at</span> <span style=''>time</span> <span style=''>t</span> <span style=''>BPTD</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discovers</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>overlapping</span> <span style=''>country</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>community</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>memberships</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>communities</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>it</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discovers</span> <span style=''>directed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>community</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>community</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interaction</span> <span style=''>networks</span> <span style=''>that</span> <span style=''>are</span> <span style=''>specific</span> <span style=''>to</span> <span style=''>topics</span> <span style=''>of</span> <span style=''>action</span> <span style=''>types</span> <span style=''>and</span> <span style=''>temporal</span> <span style=''>regimes</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>BPTD</span> <span style=''>yields</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>MCMC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>achieves</span> <span style=''>better</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>than</span> <span style=''>related</span> <span style=''>models</span> <span style=''>We</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>it</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discovers</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style=''>latent</span> <span ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.10304114490161002)
# 	knowledge (0.1262969588550984)
# 	segmentation (0.07191413237924865)
# 	architecture (0.08801431127012523)
# 	processing (0.1073345259391771)
# 	detection (0.12701252236135957)
# 	different (0.2661896243291592)
# 	information (0.2669051878354204)
# 	convolutional (0.14311270125223613)
# 	recognition (0.14275491949910554)
#
# Some Statistics words are:
# 	variables (0.1316708229426434)
# 	stochastic (0.13316708229426433)
# 	algorithm (0.3885286783042394)
# 	statistical (0.1571072319201995)
# 	distribution (0.1805486284289277)
# 	estimation (0.1740648379052369)
# 	theoretical (0.16159600997506235)
# 	dimensional (0.18802992518703243)
# 	inference (0.19052369077306733)
# 	regression (0.1800498753117207)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8e1beb6e-45fc-40b4-aa64-b41f79e38371" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e1beb6e-45fc-40b4-aa64-b41f79e38371")) {                    Plotly.newPlot(                        "8e1beb6e-45fc-40b4-aa64-b41f79e38371",                        [{"x":["available","alternative","demonstrate","departure","significant","automatic","consensus","statistical","negligible","responsible","structure","statistics","demonstrates","manipulations","obviously","exploration","commercially","improving","assumption","preliminary","diagnostic","successfully","simulation","resampling","hypothesis","recognition","resulting","independence","resampled","contemporary","dependency","dependence","understanding","scenarios","thresholded","interacting","furthermore","guarantees","efficiently","heterogeneity","algorithms","investigate","interested","abandoning","personalization","population","personalized","performance","separable","transferred","replacing","deflating","spatiotemporal","contribute","classification","architecture","interestingly","computationally","convolution","indicates","rethinking","convolutional","outperforms","efficient","capturing","inception","convolutions","detection","understand","processor","specialization","explaining","separation","described","bottleneck","presenting","neuromorphic","abstraction","traditional","previously","memristor","integrate","advantages","computation","implementation","platforms","architectures","computing","introduce","currently","technology","specification","processing","instruction","difficult","describing","principles","capabilities","implement","optimization","combinations","factorization","formulations","principal","demonstrating","experiments","dictionary","stochastic","component","variations","convergence","naturally","algorithm","modelling","gracefully","presented","approximations","neuroscience","experimentation","mechanical","conditions","simulations","limitation","plentiful","engineering","approaches","summarize","generalize","predictive","predicting","inexpensive","environment","different","increasingly","computational","interaction","partially","psychology","cognitive","reinforcement","essential","properties","normative","observable","implemented","processes","behavioral","functions","benchmark","applicable","characteristics","technique","dirichlet","generalized","qualities","synthetic","unsupervised","modification","backgrounds","occlusion","performing","demonstrated","localization","framework","describes","inference","arbitrary","accomplish","extracted","represent","dependent","illustrate","distribution","mimicking","illustration","expansion","controller","variables","posterior","predictions","parameter","estimated","respectively","pertinent","important","extraction","prediction","interpretability","universal","outperformed","developed","molecular","simultaneously","evaluation","compounds","constructed","containing","selection","objectives","descriptors","construct","intervention","quantitative","application","regression","relationship","interpretable","fingerprints","cardinality","explicitly","dimensionality","kolmogorov","satisfies","parameterized","dimension","characterize","stationary","necessary","differential","underlying","direction","characterization","estimates","establish","discounted","consistently","correspond","equilibria","sufficient","competitive","uncertainty","constraints","definition","rationality","classical","parametric","recovered","compressed","considerably","estimating","addresses","acquisition","transform","techniques","measurements","approximately","intensity","complexity","logarithmic","optimality","reproducing","randomized","projection","dimensional","prohibitive"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	thresholded
# 	pertinent
# 	cytometry
# 	disaggregation
# 	appliance
# 	practicing
# 	divisible
# 	covariances
# 	geodesics
# 	prevention
# 	unspecified
# 	semiparametric
# 	sophistication
# 	concentrates
# 	logarithmically
# 	modulation
# 	staleness
# 	modulating
# 	parameterizes
# 	uncontaminated
# Some words which never appear in Statistics papers:
# 	commercially
# 	rethinking
# 	specialization
# 	memristor
# 	instruction
# 	facilities
# 	laparoscopic
# 	cholecystectomy
# 	argumentation
# 	nonmonotonic
# 	cryptanalysis
# 	morphable
# 	orthographic
# 	necessitating
# 	reflexivity
# 	reflexive
# 	replicating
# 	deformation
# 	additions
# 	gazetteers

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.074936195073952e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7591666666666667
